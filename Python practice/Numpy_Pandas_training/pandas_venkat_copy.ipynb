# %%
import pandas as pd
df = pd.read_csv('./cr_loan2.csv')
df.shape
# Out:
# (32581, 12)

# %% [markdown]
# # dropping duplicates

# %%
df.shape
# Out:
# (32581, 12)

# %%
df.drop_duplicates(subset=['person_income','person_age'],keep='first').shape
# Out:
# (10195, 12)

# %%
# to see duplicate records count
print(df[df.duplicated(keep=False)].shape)
duplicates=df[df.duplicated(keep=False)]
# Out:
# (330, 12)

# %%
#duplicated records
duplicates.head()
# Out:
#      person_age  person_income person_home_ownership  person_emp_length  \
# 14           23         115000                  RENT                2.0
# 238          22         183000              MORTGAGE                3.0
# 252          24          85000                  RENT                5.0
# 591          26          20000              MORTGAGE                5.0
# 740          21          21600                   OWN                NaN
#
#     loan_intent loan_grade  loan_amnt  loan_int_rate  loan_status  \
# 14    EDUCATION          A      35000           7.90            0
# 238   EDUCATION          A       1000            NaN            0
# 252     MEDICAL          B      25000          10.62            0
# 591     MEDICAL          A       4800           5.99            0
# 740     VENTURE          A       7125           6.99            0
#
#      loan_percent_income cb_person_default_on_file  cb_person_cred_hist_length
# ...

# %%
df.drop_duplicates(keep='first',inplace=True)

# %%
df.drop_duplicates(keep='last',inplace=True)

# %%
df.drop_duplicates(subset=['person_income','person_age'],keep=False).shape
# Out:
# (6397, 12)

# %%
df.shape
# Out:
# (32416, 12)

# %% [markdown]
# ## Renaming columns

# %%
# 1st waying of renaming cols

# %%
df.columns
# Out:
# Index(['person_age', 'person_income', 'person_home_ownership',
#        'person_emp_length', 'loan_intent', 'loan_grade', 'loan_amnt',
#        'loan_int_rate', 'loan_status', 'loan_percent_income',
#        'cb_person_default_on_file', 'cb_person_cred_hist_length'],
#       dtype='object')

# %%
df.rename(columns={"person_age": "age", "person_income": "income"}).head()
# Out:
#    age  income person_home_ownership  person_emp_length loan_intent  \
# 0   22   59000                  RENT              123.0    PERSONAL
# 1   21    9600                   OWN                5.0   EDUCATION
# 2   25    9600              MORTGAGE                1.0     MEDICAL
# 3   23   65500                  RENT                4.0     MEDICAL
# 4   24   54400                  RENT                8.0     MEDICAL
#
#   loan_grade  loan_amnt  loan_int_rate  loan_status  loan_percent_income  \
# 0          D      35000          16.02            1                 0.59
# 1          B       1000          11.14            0                 0.10
# 2          C       5500          12.87            1                 0.57
# 3          C      35000          15.23            1                 0.53
# 4          C      35000          14.27            1                 0.55
#
#   cb_person_default_on_file  cb_person_cred_hist_length
# 0                         Y                           3
# ...

# %%
df.columns
# Out:
# Index(['person_age', 'person_income', 'person_home_ownership',
#        'person_emp_length', 'loan_intent', 'loan_grade', 'loan_amnt',
#        'loan_int_rate', 'loan_status', 'loan_percent_income',
#        'cb_person_default_on_file', 'cb_person_cred_hist_length'],
#       dtype='object')

# %%
df.rename(columns={"person_age": "age", "person_income": "income"},inplace=True)

# %%
df.columns
# Out:
# Index(['age', 'income', 'person_home_ownership', 'person_emp_length',
#        'loan_intent', 'loan_grade', 'loan_amnt', 'loan_int_rate',
#        'loan_status', 'loan_percent_income', 'cb_person_default_on_file',
#        'cb_person_cred_hist_length'],
#       dtype='object')

# %%
# 2nd way of doing things

# %%
cols_name=['a','b','c','d','e','f','g','h','i','j','k','l']

# %%
df.columns=cols_name

# %%
df.columns
# Out:
# Index(['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j', 'k', 'l'], dtype='object')

# %%
df.head()
# Out:
#     a      b         c      d          e  f      g      h  i     j  k  l
# 0  22  59000      RENT  123.0   PERSONAL  D  35000  16.02  1  0.59  Y  3
# 1  21   9600       OWN    5.0  EDUCATION  B   1000  11.14  0  0.10  N  2
# 2  25   9600  MORTGAGE    1.0    MEDICAL  C   5500  12.87  1  0.57  N  3
# 3  23  65500      RENT    4.0    MEDICAL  C  35000  15.23  1  0.53  N  2
# 4  24  54400      RENT    8.0    MEDICAL  C  35000  14.27  1  0.55  Y  4

# %% [markdown]
# # Sorting

# %%
df.head()
# Out:
#     a      b         c      d          e  f      g      h  i     j  k  l
# 0  22  59000      RENT  123.0   PERSONAL  D  35000  16.02  1  0.59  Y  3
# 1  21   9600       OWN    5.0  EDUCATION  B   1000  11.14  0  0.10  N  2
# 2  25   9600  MORTGAGE    1.0    MEDICAL  C   5500  12.87  1  0.57  N  3
# 3  23  65500      RENT    4.0    MEDICAL  C  35000  15.23  1  0.53  N  2
# 4  24  54400      RENT    8.0    MEDICAL  C  35000  14.27  1  0.55  Y  4

# %%
df.sort_values(['a'],ascending=True).head(20)
# Out:
#         a       b         c    d                  e  f      g      h  i     j  \
# 11889  20   77000  MORTGAGE  4.0            VENTURE  A   6000   8.00  0  0.08
# 7327   20   42000      RENT  4.0            VENTURE  B   6500  11.71  0  0.15
# 11902  20   77052  MORTGAGE  4.0          EDUCATION  B  24250  11.36  0  0.31
# 15830  20  188004  MORTGAGE  4.0          EDUCATION  A   2000   8.59  0  0.01
# 17196  20   65000  MORTGAGE  4.0            VENTURE  B   4800   9.99  0  0.07
# 16339  20  188004  MORTGAGE  4.0           PERSONAL  A   2000   8.59  0  0.01
# 13918  20   98000  MORTGAGE  4.0          EDUCATION  D  24250    NaN  0  0.25
# 9926   20   65000  MORTGAGE  4.0          EDUCATION  B   4800   9.99  0  0.07
# 12943  20   85920  MORTGAGE  3.0  DEBTCONSOLIDATION  A  12000   8.49  0  0.14
# 1313   20   64000      RENT  3.0            VENTURE  D  16000  15.31  1  0.25
# 14827  20  115731  MORTGAGE  4.0  DEBTCONSOLIDATION  B   9625  10.74  0  0.08
# ...

# %%
df.sort_values(['a','b'],ascending=False,inplace=True)

# %%
df.head()
# Out:
#          a        b         c     d          e  f      g      h  i     j  k  \
# 32297  144  6000000  MORTGAGE  12.0   PERSONAL  C   5000  12.73  0  0.00  N
# 81     144   250000      RENT   4.0    VENTURE  C   4800  13.57  0  0.02  N
# 183    144   200000  MORTGAGE   4.0  EDUCATION  B   6000  11.86  0  0.03  N
# 575    123    80004      RENT   2.0  EDUCATION  B  20400  10.25  0  0.25  N
# 747    123    78000      RENT   7.0    VENTURE  B  20000    NaN  0  0.26  N
#
#         l
# 32297  25
# 81      3
# 183     2
# 575     3
# 747     4
