# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

data=pd.read_csv('/home/venkat/Documents/LearnML/Python/Data/pokemon-challenge/pokemon.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-12803f11cc28> in <module>()
#       4 import seaborn as sns
#       5
# ----> 6 data=pd.read_csv('/home/venkat/Documents/LearnML/Python/Data/pokemon-challenge/pokemon.csv')
#
# ...

# %%
data.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-6208d269f320> in <module>()
# ----> 1 data.info()
#
# NameError: name 'data' is not defined

# %%
data.columns

# %%
data.Speed.plot(kind='line',color='g',label='Speed',linewidth=1,alpha=0.5,grid=True,linestyle=':')
data.Defense.plot(color= 'r',label = 'Defense',linewidth=1,alpha=0.5,grid=True,linestyle='-.')
plt.legend(loc='upper right')
plt.title("line plot")
plt.xlabel("x axis")
plt.ylabel("y axis")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-8ef2d2339a52> in <module>()
# ----> 1 data.Speed.plot(kind='line',color='g',label='Speed',linewidth=1,alpha=0.5,grid=True,linestyle=':')
#       2 data.Defense.plot(color= 'r',label = 'Defense',linewidth=1,alpha=0.5,grid=True,linestyle='-.')
#       3 plt.legend(loc='upper right')
#       4 plt.title("line plot")
#       5 plt.xlabel("x axis")
#
# NameError: name 'data' is not defined

# %%
data.plot(kind='scatter',x='Attack',y='Defense',alpha=0.5,color='red')
plt.xlabel('Attack')
plt.ylabel('Defence')
plt.title('Attack Defense scatter plot')
# Out:
# Text(0.5,1,'Attack Defense scatter plot')

# %%
data.Speed.plot(kind='hist',bins=50,figsize=(15,15))

# %%
data.Speed.plot(kind='hist',bins=50)
plt.clf()

# %%
dictionary={'spain':'madrid','usa':'vegas'}
print(dictionary.keys())
print(dictionary.values())

# %%
dictionary['spain']='barcelona'
print(dictionary)
dictionary['france']='paris'
print(dictionary)
del dictionary['spain']
print(dictionary)
print('france' in dictionary)
dictionary.clear()
print(dictionary)
# Out:
# {'spain': 'barcelona', 'usa': 'vegas'}
# {'spain': 'barcelona', 'usa': 'vegas', 'france': 'paris'}
# {'usa': 'vegas', 'france': 'paris'}
# True
# {}

# %%
  #del dictionary  
  print(dictionary)
# Out:
# {}

# %%
data=pd.read_csv('/home/venkat/Documents/LearnML/Python/pokemon-challenge/pokemon.csv')
series=data['Defense']
print(type(series))
df=data[['Defense']]
print(type(df))
# Out:
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.frame.DataFrame'>

# %%
data.head(10)
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>#</th>
#       <th>Name</th>
#       <th>Type 1</th>
#       <th>Type 2</th>
#       <th>HP</th>
#       <th>Attack</th>
#       <th>Defense</th>
#       <th>Sp. Atk</th>
#       <th>Sp. Def</th>
#       <th>Speed</th>
#       <th>Generation</th>
#       <th>Legendary</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>Bulbasaur</td>
#       <td>Grass</td>
#       <td>Poison</td>
#       <td>45</td>
#       <td>49</td>
#       <td>49</td>
#       <td>65</td>
#       <td>65</td>
#       <td>45</td>
#       <td>1</td>
#       <td>False</td>
#     </tr>
#     <tr>
# ...

# %%
#seaborn plot heatmap
f,ax=plt.subplots(figsize=(18,18))
sns.heatmap(data.corr(),annot=True,linewidths=0.5,fmt= '.1f',ax=ax)

# %%
x=data['Defense']>200
x
data[x]

# %%
x=(np.logical_and(data['Attack']>100,data['Defense']>200))
#data[x]
data[(data['Attack']>100) & (data['Defense']>200)]
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>#</th>
#       <th>Name</th>
#       <th>Type 1</th>
#       <th>Type 2</th>
#       <th>HP</th>
#       <th>Attack</th>
#       <th>Defense</th>
#       <th>Sp. Atk</th>
#       <th>Sp. Def</th>
#       <th>Speed</th>
#       <th>Generation</th>
#       <th>Legendary</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>224</th>
#       <td>225</td>
#       <td>Mega Steelix</td>
#       <td>Steel</td>
#       <td>Ground</td>
#       <td>75</td>
#       <td>125</td>
#       <td>230</td>
#       <td>55</td>
#       <td>95</td>
#       <td>30</td>
#       <td>2</td>
#       <td>False</td>
#     </tr>
#     <tr>
# ...

# %%
i=0
while i<5:
    print(i)
    i+=1
print ("i is now", i)

# %%
lis = [1, 2, 3, 4, 5]
for i in lis:
    print('i is', +i)

for index, value in enumerate(lis):
    print(index, ' is ', value)

dictionary = {'spain': 'madrid', 'tn': 'chennai'}

for key, value in dictionary.items():
    print(key, ":", value)

#data[['Speed']][0:10]
for index,value in data[['Attack']][0:1].iterrows():
   print(index,':',value)
# Out:
# i is 1
# i is 2
# i is 3
# i is 4
# i is 5
# 0  is  1
# 1  is  2
# 2  is  3
# 3  is  4
# 4  is  5
# spain : madrid
# tn : chennai
# 0 : Attack    49
# Name: 0, dtype: int64

# %%
def tuble_ex():
    "this is doc line"
    t=(1,2,3)
    return  t
a,b,c=tuble_ex()
print(a,b,c)

# %%
x=2
def f():
    #x=3
    y=x*3
    return y
print(x)
print(f())

import  builtins
#dir(builtins)

def squareof5():
    "square of 5 method"
    def sum():
        "sum of 5"
        x=2
        y=3
        z=x+y
        return z
    return sum()**2
print(squareof5())

def f(a,b=1,c=2):
    c=a+b+c
    return c

print(f(1))
print(f(1,2))

# %%
#flexible arguments
def f(*args):
    for i in args:
        print(i)

f(1,2,34)

def f(**kwargs):
     "print key and values in dictionary"
     for key,values in kwargs.items():
         print( key,":", values)
f(country='spain',capital='madrid',popu=23893982)
# Out:
# 1
# 2
# 34
# country : spain
# capital : madrid
# popu : 23893982

# %%
#lambda methods
square= lambda x:x**2
print(square(3))
tot=lambda x,y,z:x+y+z
print(tot(1,2,3))
numlist=[1,2,3]
y=map(lambda x:x**2,numlist)
print(list(y))
# Out:
# 9
# 6
# [1, 4, 9]

# %%
name="venkat raman"
iterator=iter(name)
print(next(iterator))
print(*iterator)

# %%
list1 = [1,2,3,4]
list2 = [5,6,7,8]
z = zip(list1,list2)
print(z)
z_list = list(z)
print(z_list)
# Out:
# ...
# [(1, 5), (2, 6), (3, 7), (4, 8)]

# %%
un_zip = zip(*z_list)
un_list1,un_list2 = list(un_zip) # unzip returns tuble
print(un_list1)
print(un_list2)
print(type(un_list2))
# Out:
# (1, 2, 3, 4)
# (5, 6, 7, 8)
# <class 'tuple'>

# %%
num1=[1,2,3,4]
num2=[i+1 for i in num1]
print(num2)
# Out:
# [2, 3, 4, 5]

# %%
num=[5,10,15]
num2=[i**2 if i==10 else i-5 if i<7 else i+5 for i in num]
print(num2)
# Out:
# [0, 100, 20]

# %%
threshold_speed=sum(data.Speed)/len(data)
data["speed_level"]=["high" if i>threshold_speed else "low"  for i in data.Speed]
data.loc[:10,["speed_level","Name"]]
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>speed_level</th>
#       <th>Name</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>low</td>
#       <td>Bulbasaur</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>low</td>
#       <td>Ivysaur</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>high</td>
#       <td>Venusaur</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>high</td>
#       <td>Mega Venusaur</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>low</td>
#       <td>Charmander</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>high</td>
#       <td>Charmeleon</td>
#     </tr>
#     <tr>
# ...

# %%
data=pd.read_csv("/home/venkat/Documents/LearnML/Python/pokemon-challenge/pokemon.csv")
data.head()
data.tail()
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>#</th>
#       <th>Name</th>
#       <th>Type 1</th>
#       <th>Type 2</th>
#       <th>HP</th>
#       <th>Attack</th>
#       <th>Defense</th>
#       <th>Sp. Atk</th>
#       <th>Sp. Def</th>
#       <th>Speed</th>
#       <th>Generation</th>
#       <th>Legendary</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>795</th>
#       <td>796</td>
#       <td>Diancie</td>
#       <td>Rock</td>
#       <td>Fairy</td>
#       <td>50</td>
#       <td>100</td>
#       <td>150</td>
#       <td>100</td>
#       <td>150</td>
#       <td>50</td>
#       <td>6</td>
#       <td>True</td>
#     </tr>
#     <tr>
# ...

# %%
data.columns

# %%
data.shape

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 12 columns):
# #             800 non-null int64
# Name          799 non-null object
# Type 1        800 non-null object
# Type 2        414 non-null object
# HP            800 non-null int64
# Attack        800 non-null int64
# Defense       800 non-null int64
# Sp. Atk       800 non-null int64
# Sp. Def       800 non-null int64
# Speed         800 non-null int64
# Generation    800 non-null int64
# Legendary     800 non-null bool
# dtypes: bool(1), int64(8), object(3)
# memory usage: 69.6+ KB

# %%
print(data['Type 1'].value_counts(dropna=False))

# %%
data.describe()
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>#</th>
#       <th>HP</th>
#       <th>Attack</th>
#       <th>Defense</th>
#       <th>Sp. Atk</th>
#       <th>Sp. Def</th>
#       <th>Speed</th>
#       <th>Generation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>count</th>
#       <td>800.0000</td>
#       <td>800.000000</td>
#       <td>800.000000</td>
#       <td>800.000000</td>
#       <td>800.000000</td>
#       <td>800.000000</td>
#       <td>800.000000</td>
#       <td>800.00000</td>
#     </tr>
#     <tr>
#       <th>mean</th>
#       <td>400.5000</td>
#       <td>69.258750</td>
#       <td>79.001250</td>
#       <td>73.842500</td>
# ...

# %%
data.boxplot(column='Attack',by= 'Legendary')
# Out:
# /home/venkat/anaconda3/lib/python3.6/site-packages/numpy/core/fromnumeric.py:57: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   return getattr(obj, method)(*args, **kwds)

# %%
data_new=data.head()
data_new
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>#</th>
#       <th>Name</th>
#       <th>Type 1</th>
#       <th>Type 2</th>
#       <th>HP</th>
#       <th>Attack</th>
#       <th>Defense</th>
#       <th>Sp. Atk</th>
#       <th>Sp. Def</th>
#       <th>Speed</th>
#       <th>Generation</th>
#       <th>Legendary</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>Bulbasaur</td>
#       <td>Grass</td>
#       <td>Poison</td>
#       <td>45</td>
#       <td>49</td>
#       <td>49</td>
#       <td>65</td>
#       <td>65</td>
#       <td>45</td>
#       <td>1</td>
#       <td>False</td>
#     </tr>
#     <tr>
# ...

# %%
#data melting
melted=pd.melt(frame=data_new,id_vars="Name",value_vars=['Attack','Defense'])
melted
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Name</th>
#       <th>variable</th>
#       <th>value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Bulbasaur</td>
#       <td>Attack</td>
#       <td>49</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Ivysaur</td>
#       <td>Attack</td>
#       <td>62</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Venusaur</td>
#       <td>Attack</td>
#       <td>82</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Mega Venusaur</td>
#       <td>Attack</td>
#       <td>100</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Charmander</td>
#       <td>Attack</td>
# ...

# %%
melted.pivot(index="Name",columns="variable",values="value")
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>variable</th>
#       <th>Attack</th>
#       <th>Defense</th>
#     </tr>
#     <tr>
#       <th>Name</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Bulbasaur</th>
#       <td>49</td>
#       <td>49</td>
#     </tr>
#     <tr>
#       <th>Charmander</th>
#       <td>52</td>
#       <td>43</td>
#     </tr>
#     <tr>
#       <th>Ivysaur</th>
#       <td>62</td>
#       <td>63</td>
#     </tr>
#     <tr>
#       <th>Mega Venusaur</th>
#       <td>100</td>
#       <td>123</td>
#     </tr>
#     <tr>
#       <th>Venusaur</th>
#       <td>82</td>
#       <td>83</td>
#     </tr>
#   </tbody>
# ...

# %%
data1=data.head()
data2=data.tail()
concat_data_row=pd.concat([data1,data2],axis=0,ignore_index=True)
concat_data_row
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>#</th>
#       <th>Name</th>
#       <th>Type 1</th>
#       <th>Type 2</th>
#       <th>HP</th>
#       <th>Attack</th>
#       <th>Defense</th>
#       <th>Sp. Atk</th>
#       <th>Sp. Def</th>
#       <th>Speed</th>
#       <th>Generation</th>
#       <th>Legendary</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>Bulbasaur</td>
#       <td>Grass</td>
#       <td>Poison</td>
#       <td>45</td>
#       <td>49</td>
#       <td>49</td>
#       <td>65</td>
#       <td>65</td>
#       <td>45</td>
#       <td>1</td>
#       <td>False</td>
#     </tr>
#     <tr>
# ...

# %%
data11=data["Attack"].head()
data22=data["Defense"].head()
concat_data_col=pd.concat([data11,data22],axis=1)
concat_data_col
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Attack</th>
#       <th>Defense</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>49</td>
#       <td>49</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>62</td>
#       <td>63</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>82</td>
#       <td>83</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>100</td>
#       <td>123</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>52</td>
#       <td>43</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
data.dtypes
# Out:
# #              int64
# Name          object
# Type 1        object
# Type 2        object
# HP             int64
# Attack         int64
# Defense        int64
# Sp. Atk        int64
# Sp. Def        int64
# Speed          int64
# Generation     int64
# Legendary       bool
# dtype: object

# %%
data["Type 1"]=data["Type 1"].astype("category")
data["Speed"]=data["Speed"].astype("float")
data.dtypes
# Out:
# #                int64
# Name            object
# Type 1        category
# Type 2          object
# HP               int64
# Attack           int64
# Defense          int64
# Sp. Atk          int64
# Sp. Def          int64
# Speed          float64
# Generation       int64
# Legendary         bool
# dtype: object

# %%
data.head()
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>#</th>
#       <th>Name</th>
#       <th>Type 1</th>
#       <th>Type 2</th>
#       <th>HP</th>
#       <th>Attack</th>
#       <th>Defense</th>
#       <th>Sp. Atk</th>
#       <th>Sp. Def</th>
#       <th>Speed</th>
#       <th>Generation</th>
#       <th>Legendary</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>Bulbasaur</td>
#       <td>Grass</td>
#       <td>Poison</td>
#       <td>45</td>
#       <td>49</td>
#       <td>49</td>
#       <td>65</td>
#       <td>65</td>
#       <td>45</td>
#       <td>1</td>
#       <td>False</td>
#     </tr>
#     <tr>
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 12 columns):
# #             800 non-null int64
# Name          799 non-null object
# Type 1        800 non-null category
# Type 2        414 non-null object
# HP            800 non-null int64
# Attack        800 non-null int64
# Defense       800 non-null int64
# Sp. Atk       800 non-null int64
# Sp. Def       800 non-null int64
# Speed         800 non-null float64
# Generation    800 non-null int64
# Legendary     800 non-null bool
# dtypes: bool(1), category(1), float64(1), int64(7), object(2)
# memory usage: 64.9+ KB

# %%
data["Type 2"].value_counts(dropna=False)
# Out:
# NaN         386
# Flying       97
# Ground       35
# Poison       34
# Psychic      33
# Fighting     26
# Grass        25
# Fairy        23
# Steel        22
# Dark         20
# Dragon       18
# Water        14
# Rock         14
# Ghost        14
# Ice          14
# Fire         12
# Electric      6
# Normal        4
# Bug           3
# Name: Type 2, dtype: int64

# %%
data1=data
data1["Type 2"].dropna(inplace=True)

# %%
assert data["Type 2"].notnull().all()

# %%
data["Type 2"].fillna("empty",inplace=True)

# %%
data["Type 2"].value_counts(dropna=False)

# %%
assert  data["Type 2"].notnull().all()

# %%
#Creating data frames
country=["India","Pakistan"]
population=["11","12"]
print(population)
list_label=["country","population"]

list_col=[country,population]
print(list_col)
zipped=list(zip(list_label,list_col))
dict_data=dict(zipped)
print(dict_data.items())
df=pd.DataFrame(dict_data)
df
# Out:
# ['11', '12']
# [['India', 'Pakistan'], ['11', '12']]
# dict_items([('country', ['India', 'Pakistan']), ('population', ['11', '12'])])

# %%
df["Capital"]=["delhi","islamabad"]
df
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>country</th>
#       <th>population</th>
#       <th>Income</th>
#       <th>Capital</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>India</td>
#       <td>11</td>
#       <td>0</td>
#       <td>delhi</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Pakistan</td>
#       <td>12</td>
#       <td>0</td>
#       <td>islamabad</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
df["Income"]=0
df
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>country</th>
#       <th>population</th>
#       <th>Income</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>India</td>
#       <td>11</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Pakistan</td>
#       <td>12</td>
#       <td>0</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
data1=data.loc[:,["Attack","Defense","Speed"]]
data1.plot()

# %%
data1.plot(subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f8e50202518>,
# ...
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f8e50122278>], dtype=object)

# %%
data1.plot(kind="scatter",x="Attack",y="Defense")

# %%
data1.plot(kind="hist",y="Defense",bins=10,range=(0,250),normed=True)

# %%
fig,axes=plt.subplots(nrows=2,ncols=1)
data1.plot(kind='hist',bins=50,range=(0,250),y="Defense",normed=True,ax=axes[0])
data1.plot(kind='hist',bins=50,range=(0,250),y="Defense",ax=axes[1],normed=True,cumulative=True)

# %%
data.describe()
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>#</th>
#       <th>HP</th>
#       <th>Attack</th>
#       <th>Defense</th>
#       <th>Sp. Atk</th>
#       <th>Sp. Def</th>
#       <th>Speed</th>
#       <th>Generation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>count</th>
#       <td>800.0000</td>
#       <td>800.000000</td>
#       <td>800.000000</td>
#       <td>800.000000</td>
#       <td>800.000000</td>
#       <td>800.000000</td>
#       <td>800.000000</td>
#       <td>800.00000</td>
#     </tr>
#     <tr>
#       <th>mean</th>
#       <td>400.5000</td>
#       <td>69.258750</td>
#       <td>79.001250</td>
#       <td>73.842500</td>
# ...

# %%
time_list=["1992-03-08","1993-04-10"]
print(type(time_list[1]))
datetime_object=pd.to_datetime(time_list)
print(type(datetime_object))
# Out:
# <class 'str'>
# <class 'pandas.core.indexes.datetimes.DatetimeIndex'>

# %%
data2 = data.head()
date_list = ["1992-01-10","1992-02-10","1992-03-10","1993-03-15","1993-03-16"]
datetime_object = pd.to_datetime(date_list)
data2["date"] = datetime_object
# lets make date as index
data2= data2.set_index("date")
data2
# Out:
# /home/venkat/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>#</th>
#       <th>Name</th>
#       <th>Type 1</th>
#       <th>Type 2</th>
#       <th>HP</th>
#       <th>Attack</th>
#       <th>Defense</th>
#       <th>Sp. Atk</th>
#       <th>Sp. Def</th>
#       <th>Speed</th>
# ...

# %%
print(data2.loc["1992-01-10"])
# Out:
# #                     1
# Name          Bulbasaur
# Type 1            Grass
# Type 2           Poison
# HP                   45
# Attack               49
# Defense              49
# Sp. Atk              65
# Sp. Def              65
# Speed                45
# Generation            1
# Legendary         False
# Name: 1992-01-10 00:00:00, dtype: object

# %%
print(data2.loc["1992-03-10":"1993-03-16"])
# Out:
#             #           Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# date
# 1992-03-10  3       Venusaur  Grass  Poison  80      82       83      100
# 1993-03-15  4  Mega Venusaur  Grass  Poison  80     100      123      122
# 1993-03-16  5     Charmander   Fire     NaN  39      52       43       60
#
#             Sp. Def  Speed  Generation  Legendary
# date
# 1992-03-10      100   80.0           1      False
# 1993-03-15      120   80.0           1      False
# 1993-03-16       50   65.0           1      False

# %%
data2.resample("A").mean()
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>#</th>
#       <th>HP</th>
#       <th>Attack</th>
#       <th>Defense</th>
#       <th>Sp. Atk</th>
#       <th>Sp. Def</th>
#       <th>Speed</th>
#       <th>Generation</th>
#       <th>Legendary</th>
#     </tr>
#     <tr>
#       <th>date</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1992-12-31</th>
#       <td>2.0</td>
#       <td>61.666667</td>
#       <td>64.333333</td>
#       <td>65.0</td>
#       <td>81.666667</td>
# ...

# %%
data2.resample("M").mean()
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>#</th>
#       <th>HP</th>
#       <th>Attack</th>
#       <th>Defense</th>
#       <th>Sp. Atk</th>
#       <th>Sp. Def</th>
#       <th>Speed</th>
#       <th>Generation</th>
#       <th>Legendary</th>
#     </tr>
#     <tr>
#       <th>date</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1992-01-31</th>
#       <td>1.0</td>
#       <td>45.0</td>
#       <td>49.0</td>
#       <td>49.0</td>
#       <td>65.0</td>
#       <td>65.0</td>
# ...

# %%
data2.resample("M").first().interpolate("linear")
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>#</th>
#       <th>Name</th>
#       <th>Type 1</th>
#       <th>Type 2</th>
#       <th>HP</th>
#       <th>Attack</th>
#       <th>Defense</th>
#       <th>Sp. Atk</th>
#       <th>Sp. Def</th>
#       <th>Speed</th>
#       <th>Generation</th>
#       <th>Legendary</th>
#     </tr>
#     <tr>
#       <th>date</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1992-01-31</th>
# ...

# %%
data2.resample("M").mean().interpolate("linear")
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>#</th>
#       <th>HP</th>
#       <th>Attack</th>
#       <th>Defense</th>
#       <th>Sp. Atk</th>
#       <th>Sp. Def</th>
#       <th>Speed</th>
#       <th>Generation</th>
#       <th>Legendary</th>
#     </tr>
#     <tr>
#       <th>date</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1992-01-31</th>
#       <td>1.000</td>
#       <td>45.000000</td>
#       <td>49.0</td>
#       <td>49.0</td>
#       <td>65.00</td>
#       <td>65.00</td>
# ...

# %%
data=pd.read_csv('/home/venkat/Documents/LearnML/Python/pokemon-challenge/pokemon.csv')
data.set_index("#")
data.head()
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>#</th>
#       <th>Name</th>
#       <th>Type 1</th>
#       <th>Type 2</th>
#       <th>HP</th>
#       <th>Attack</th>
#       <th>Defense</th>
#       <th>Sp. Atk</th>
#       <th>Sp. Def</th>
#       <th>Speed</th>
#       <th>Generation</th>
#       <th>Legendary</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>Bulbasaur</td>
#       <td>Grass</td>
#       <td>Poison</td>
#       <td>45</td>
#       <td>49</td>
#       <td>49</td>
#       <td>65</td>
#       <td>65</td>
#       <td>45</td>
#       <td>1</td>
#       <td>False</td>
#     </tr>
#     <tr>
# ...

# %%
data[0:5]["Name"]
# Out:
# 0        Bulbasaur
# 1          Ivysaur
# 2         Venusaur
# 3    Mega Venusaur
# 4       Charmander
# Name: Name, dtype: object

# %%
data.Name[0]
# Out:
# 'Bulbasaur'

# %%
data.loc[1,["Name"]]
# Out:
# Name    Ivysaur
# Name: 1, dtype: object

# %%
data.loc[0:10,["Name","HP"]]
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Name</th>
#       <th>HP</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Bulbasaur</td>
#       <td>45</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Ivysaur</td>
#       <td>60</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Venusaur</td>
#       <td>80</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Mega Venusaur</td>
#       <td>80</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Charmander</td>
#       <td>39</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>Charmeleon</td>
#       <td>58</td>
#     </tr>
#     <tr>
#       <th>6</th>
# ...

# %%
data[["Name","HP"]]
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Name</th>
#       <th>HP</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Bulbasaur</td>
#       <td>45</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Ivysaur</td>
#       <td>60</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Venusaur</td>
#       <td>80</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Mega Venusaur</td>
#       <td>80</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Charmander</td>
#       <td>39</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>Charmeleon</td>
#       <td>58</td>
#     </tr>
#     <tr>
#       <th>6</th>
# ...

# %%
print(type(data["HP"]))
print(type(data[["HP"]]))
# Out:
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.frame.DataFrame'>

# %%
data
data.loc[0:10,"Name":"Defense"]
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Name</th>
#       <th>Type 1</th>
#       <th>Type 2</th>
#       <th>HP</th>
#       <th>Attack</th>
#       <th>Defense</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Bulbasaur</td>
#       <td>Grass</td>
#       <td>Poison</td>
#       <td>45</td>
#       <td>49</td>
#       <td>49</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Ivysaur</td>
#       <td>Grass</td>
#       <td>Poison</td>
#       <td>60</td>
#       <td>62</td>
#       <td>63</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Venusaur</td>
#       <td>Grass</td>
#       <td>Poison</td>
# ...

# %%
data.loc[10:1:-1,"Defense":"Name":-1]
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Defense</th>
#       <th>Attack</th>
#       <th>HP</th>
#       <th>Type 2</th>
#       <th>Type 1</th>
#       <th>Name</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>10</th>
#       <td>80</td>
#       <td>63</td>
#       <td>59</td>
#       <td>NaN</td>
#       <td>Water</td>
#       <td>Wartortle</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>65</td>
#       <td>48</td>
#       <td>44</td>
#       <td>NaN</td>
#       <td>Water</td>
#       <td>Squirtle</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>78</td>
#       <td>104</td>
#       <td>78</td>
#       <td>Flying</td>
# ...

# %%
data.loc[1:10,"Speed":]
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Speed</th>
#       <th>Generation</th>
#       <th>Legendary</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>60</td>
#       <td>1</td>
#       <td>False</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>80</td>
#       <td>1</td>
#       <td>False</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>80</td>
#       <td>1</td>
#       <td>False</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>65</td>
#       <td>1</td>
#       <td>False</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>80</td>
#       <td>1</td>
#       <td>False</td>
#     </tr>
#     <tr>
# ...

# %%
boolean=data["Defense"]>200
data[boolean]
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>#</th>
#       <th>Name</th>
#       <th>Type 1</th>
#       <th>Type 2</th>
#       <th>HP</th>
#       <th>Attack</th>
#       <th>Defense</th>
#       <th>Sp. Atk</th>
#       <th>Sp. Def</th>
#       <th>Speed</th>
#       <th>Generation</th>
#       <th>Legendary</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>224</th>
#       <td>225</td>
#       <td>Mega Steelix</td>
#       <td>Steel</td>
#       <td>Ground</td>
#       <td>75</td>
#       <td>125</td>
#       <td>230</td>
#       <td>55</td>
#       <td>95</td>
#       <td>30</td>
#       <td>2</td>
#       <td>False</td>
#     </tr>
#     <tr>
# ...

# %%
ff=data["HP"]>150
sf=data["Speed"]>50
data[sf&ff]
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>#</th>
#       <th>Name</th>
#       <th>Type 1</th>
#       <th>Type 2</th>
#       <th>HP</th>
#       <th>Attack</th>
#       <th>Defense</th>
#       <th>Sp. Atk</th>
#       <th>Sp. Def</th>
#       <th>Speed</th>
#       <th>Generation</th>
#       <th>Legendary</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>261</th>
#       <td>262</td>
#       <td>Blissey</td>
#       <td>Normal</td>
#       <td>NaN</td>
#       <td>255</td>
#       <td>10</td>
#       <td>10</td>
#       <td>75</td>
#       <td>135</td>
#       <td>55</td>
#       <td>2</td>
#       <td>False</td>
#     </tr>
#     <tr>
# ...

# %%
data["HP"][data["Speed"]<10]
# Out:
# 230     20
# 495    135
# Name: HP, dtype: int64

# %%
def div2(n):
    return n/2
data["HP"].apply(div2)
# Out:
# 0      22.5
# 1      30.0
# 2      40.0
# 3      40.0
# 4      19.5
# 5      29.0
# 6      39.0
# 7      39.0
# 8      39.0
# 9      22.0
# 10     29.5
# 11     39.5
# 12     39.5
# 13     22.5
# 14     25.0
# 15     30.0
# 16     20.0
# 17     22.5
# 18     32.5
# 19     32.5
# 20     20.0
# 21     31.5
# 22     41.5
# 23     41.5
# 24     15.0
# 25     27.5
# 26     20.0
# 27     32.5
# 28     17.5
# 29     30.0
#        ...
# 770    47.5
# 771    39.0
# 772    33.5
# 773    25.0
# 774    22.5
# 775    34.0
# 776    45.0
# 777    28.5
# 778    21.5
# 779    42.5
# 780    24.5
# 781    22.0
# 782    27.0
# 783    29.5
# 784    32.5
# 785    27.5
# 786    37.5
# 787    42.5
# 788    27.5
# 789    47.5
# 790    20.0
# 791    42.5
# 792    63.0
# 793    63.0
# 794    54.0
# 795    25.0
# 796    25.0
# 797    40.0
# 798    40.0
# 799    40.0
# Name: HP, Length: 800, dtype: float64

# %%
data["HP"].apply(lambda n:n/2)
# Out:
# 0      22.5
# 1      30.0
# 2      40.0
# 3      40.0
# 4      19.5
# 5      29.0
# 6      39.0
# 7      39.0
# 8      39.0
# 9      22.0
# 10     29.5
# 11     39.5
# 12     39.5
# 13     22.5
# 14     25.0
# 15     30.0
# 16     20.0
# 17     22.5
# 18     32.5
# 19     32.5
# 20     20.0
# 21     31.5
# 22     41.5
# 23     41.5
# 24     15.0
# 25     27.5
# 26     20.0
# 27     32.5
# 28     17.5
# 29     30.0
#        ...
# 770    47.5
# 771    39.0
# 772    33.5
# 773    25.0
# 774    22.5
# 775    34.0
# 776    45.0
# 777    28.5
# 778    21.5
# 779    42.5
# 780    24.5
# 781    22.0
# 782    27.0
# 783    29.5
# 784    32.5
# 785    27.5
# 786    37.5
# 787    42.5
# 788    27.5
# 789    47.5
# 790    20.0
# 791    42.5
# 792    63.0
# 793    63.0
# 794    54.0
# 795    25.0
# 796    25.0
# 797    40.0
# 798    40.0
# 799    40.0
# Name: HP, Length: 800, dtype: float64

# %%
data
data["Total_Power"]=data["Defense"]+data["Attack"]
data.head()
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>#</th>
#       <th>Name</th>
#       <th>Type 1</th>
#       <th>Type 2</th>
#       <th>HP</th>
#       <th>Attack</th>
#       <th>Defense</th>
#       <th>Sp. Atk</th>
#       <th>Sp. Def</th>
#       <th>Speed</th>
#       <th>Generation</th>
#       <th>Legendary</th>
#       <th>Total_Power</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>Bulbasaur</td>
#       <td>Grass</td>
#       <td>Poison</td>
#       <td>45</td>
#       <td>49</td>
#       <td>49</td>
#       <td>65</td>
#       <td>65</td>
#       <td>45</td>
#       <td>1</td>
#       <td>False</td>
# ...

# %%
print(data.index.name)
data.index.name="index_name"
print(data.index.name)
data.head()
# Out:
# index_name
# index_name
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>#</th>
#       <th>Name</th>
#       <th>Type 1</th>
#       <th>Type 2</th>
#       <th>HP</th>
#       <th>Attack</th>
#       <th>Defense</th>
#       <th>Sp. Atk</th>
#       <th>Sp. Def</th>
#       <th>Speed</th>
#       <th>Generation</th>
#       <th>Legendary</th>
#       <th>Total_Power</th>
#     </tr>
#     <tr>
#       <th>index_name</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
# ...

# %%
data3=data.copy()
data3.index=range(100,900,1)
data3.head()
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>#</th>
#       <th>Name</th>
#       <th>Type 1</th>
#       <th>Type 2</th>
#       <th>HP</th>
#       <th>Attack</th>
#       <th>Defense</th>
#       <th>Sp. Atk</th>
#       <th>Sp. Def</th>
#       <th>Speed</th>
#       <th>Generation</th>
#       <th>Legendary</th>
#       <th>Total_Power</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>100</th>
#       <td>1</td>
#       <td>Bulbasaur</td>
#       <td>Grass</td>
#       <td>Poison</td>
#       <td>45</td>
#       <td>49</td>
#       <td>49</td>
#       <td>65</td>
#       <td>65</td>
#       <td>45</td>
#       <td>1</td>
#       <td>False</td>
# ...

# %%
data=pd.read_csv('/home/venkat/Documents/LearnML/Python/pokemon-challenge/pokemon.csv')
data.head(100)
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>#</th>
#       <th>Name</th>
#       <th>Type 1</th>
#       <th>Type 2</th>
#       <th>HP</th>
#       <th>Attack</th>
#       <th>Defense</th>
#       <th>Sp. Atk</th>
#       <th>Sp. Def</th>
#       <th>Speed</th>
#       <th>Generation</th>
#       <th>Legendary</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>Bulbasaur</td>
#       <td>Grass</td>
#       <td>Poison</td>
#       <td>45</td>
#       <td>49</td>
#       <td>49</td>
#       <td>65</td>
#       <td>65</td>
#       <td>45</td>
#       <td>1</td>
#       <td>False</td>
#     </tr>
#     <tr>
# ...

# %%
data1=data.set_index(["Type 1","Type 2"])
data1.head(20)
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>#</th>
#       <th>Name</th>
#       <th>HP</th>
#       <th>Attack</th>
#       <th>Defense</th>
#       <th>Sp. Atk</th>
#       <th>Sp. Def</th>
#       <th>Speed</th>
#       <th>Generation</th>
#       <th>Legendary</th>
#     </tr>
#     <tr>
#       <th>Type 1</th>
#       <th>Type 2</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th rowspan="4" valign="top">Grass</th>
#       <th>Poison</th>
#       <td>1</td>
# ...

# %%
data1.loc[:,["Defense","Speed"]]
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>Defense</th>
#       <th>Speed</th>
#     </tr>
#     <tr>
#       <th>Type 1</th>
#       <th>Type 2</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th rowspan="4" valign="top">Grass</th>
#       <th>Poison</th>
#       <td>49</td>
#       <td>45</td>
#     </tr>
#     <tr>
#       <th>Poison</th>
#       <td>63</td>
#       <td>60</td>
#     </tr>
#     <tr>
#       <th>Poison</th>
#       <td>83</td>
#       <td>80</td>
#     </tr>
#     <tr>
#       <th>Poison</th>
#       <td>123</td>
#       <td>80</td>
#     </tr>
#     <tr>
# ...

# %%
diction={"Treatment":["A","A","B","B"],"gender":["M","F","M","M"],"Age":["10","20","30","40"]}
df=pd.DataFrame(diction)
df
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Age</th>
#       <th>Treatment</th>
#       <th>gender</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>10</td>
#       <td>A</td>
#       <td>M</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>20</td>
#       <td>A</td>
#       <td>F</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>30</td>
#       <td>B</td>
#       <td>M</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>40</td>
#       <td>B</td>
#       <td>M</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
df.pivot(index="Age",columns="gender",values="Treatment")
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>gender</th>
#       <th>F</th>
#       <th>M</th>
#     </tr>
#     <tr>
#       <th>Age</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>10</th>
#       <td>None</td>
#       <td>A</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>A</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>30</th>
#       <td>None</td>
#       <td>B</td>
#     </tr>
#     <tr>
#       <th>40</th>
#       <td>None</td>
#       <td>B</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
df1=df.set_index(["Treatment","gender"])
df1
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>Age</th>
#     </tr>
#     <tr>
#       <th>Treatment</th>
#       <th>gender</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th rowspan="2" valign="top">A</th>
#       <th>M</th>
#       <td>10</td>
#     </tr>
#     <tr>
#       <th>F</th>
#       <td>20</td>
#     </tr>
#     <tr>
#       <th rowspan="2" valign="top">B</th>
#       <th>M</th>
#       <td>30</td>
#     </tr>
#     <tr>
#       <th>M</th>
#       <td>40</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
#df1.unstack(level=1)#level determine indexes
df2=df1.swaplevel(0,1)
df2
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>Age</th>
#     </tr>
#     <tr>
#       <th>gender</th>
#       <th>Treatment</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>M</th>
#       <th>A</th>
#       <td>10</td>
#     </tr>
#     <tr>
#       <th>F</th>
#       <th>A</th>
#       <td>20</td>
#     </tr>
#     <tr>
#       <th rowspan="2" valign="top">M</th>
#       <th>B</th>
#       <td>30</td>
#     </tr>
#     <tr>
#       <th>B</th>
#       <td>40</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
pd.melt(df,id_vars="Treatment",value_vars=["gender","Age"])
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Treatment</th>
#       <th>variable</th>
#       <th>value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>A</td>
#       <td>gender</td>
#       <td>M</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>A</td>
#       <td>gender</td>
#       <td>F</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>B</td>
#       <td>gender</td>
#       <td>M</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>B</td>
#       <td>gender</td>
#       <td>M</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>A</td>
#       <td>Age</td>
#       <td>10</td>
#     </tr>
#     <tr>
# ...

# %%
df["response"]=[10,2,3,4]

# %%
diction={"Treatment":["A","A","B","B"],"gender":["M","F","M","M"],"Age":[10,20,30,40],"response":[10,303,34,44]}
df=pd.DataFrame(diction)
df
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Age</th>
#       <th>Treatment</th>
#       <th>gender</th>
#       <th>response</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>10</td>
#       <td>A</td>
#       <td>M</td>
#       <td>10</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>20</td>
#       <td>A</td>
#       <td>F</td>
#       <td>303</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>30</td>
#       <td>B</td>
#       <td>M</td>
#       <td>34</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>40</td>
#       <td>B</td>
#       <td>M</td>
#       <td>44</td>
#     </tr>
#   </tbody>
# </table>
# ...

# %%
df.groupby("Treatment").mean()
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Age</th>
#       <th>response</th>
#     </tr>
#     <tr>
#       <th>Treatment</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>A</th>
#       <td>15.0</td>
#       <td>156.5</td>
#     </tr>
#     <tr>
#       <th>B</th>
#       <td>35.0</td>
#       <td>39.0</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
df.groupby("Treatment").Age.mean()
# Out:
# Treatment
# A    15
# B    35
# Name: Age, dtype: int64

# %%
df.groupby("Treatment")[["Age","response"]].mean()
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Age</th>
#       <th>response</th>
#     </tr>
#     <tr>
#       <th>Treatment</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>A</th>
#       <td>15.0</td>
#       <td>156.5</td>
#     </tr>
#     <tr>
#       <th>B</th>
#       <td>35.0</td>
#       <td>39.0</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 4 columns):
# Age          4 non-null int64
# Treatment    4 non-null object
# gender       4 non-null object
# response     4 non-null int64
# dtypes: int64(2), object(2)
# memory usage: 208.0+ bytes

# %%
df["Treatment"]=df["Treatment"].astype("category")
df["gender"]=df["gender"].astype("category")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 4 columns):
# Age          4 non-null int64
# Treatment    4 non-null category
# gender       4 non-null category
# response     4 non-null int64
# dtypes: category(2), int64(2)
# memory usage: 344.0 bytes
